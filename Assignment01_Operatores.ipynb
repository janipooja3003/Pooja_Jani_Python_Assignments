# %%
#Write a program to perform addition, subtraction, multiplication, division, floor division, modulus, and exponential on two numbers.
import operator as math
x = int(input("Enter first number: "))
y = int(input("Enter second number: "))
print("addition",math.add(x,y))
print("subtraction",math.sub(x,y))
print("multiplication",math.mul(x,y))
print("division",math.truediv(x,y))
print("floor division",math.floordiv(x,y))
print("modulus",math.mod(x,y))
print("exponential",math.pow(x,y))
# Out:
# Enter first number: 5
# Enter second number: 5
# addition 10
# subtraction 0
# multiplication 25
# division 1.0
# floor division 1
# modulus 0
# exponential 3125

# %%
#Swap two numbers without using a third variable.
x=5
y=6
x=x+y
y=x-y
x=x-y
print(f"x:{x} y:{y}")
# Out:
# x:6 y:5

# %%
#Find whether a number is even or odd using the modulus operator.
x= int(input("Enter a number: "))
if x%2==0:
  print("number is even")
else:
  print("number is odd")
# Out:
# Enter a number: 8967
# number is odd

# %%
#Reverse a three-digit number using arithmetic operators.
x = int(input("Enter a three digit number: "))
#for i in range(len(x)):


number_1 = x%10
number_2 = (x%100)//10
number_3 = x//100
reverse_number = number_1*100 + number_2*10 + number_3
print(reverse_number)
# Out:
# Enter a three digit number: 257
# 752

# %%
#Find the last digit and first digit of a given number.
x= int(input("Enter a number: "))
print(f"last digit: {x%10}")
first_digit = x // math.pow(10,len(str(x))-1)
print(f"fist digit: {first_digit}")
# Out:
# Enter a number: 6780646
# last digit: 6
# fist digit: 6

# %%
#Demonstrate all assignment operators (=, +=, -=, *=, /=, //=, %= and **=) on a variable.
x = int(input("Enter a number: "))
x+=5
print("+=:",x)
x-=5
print("-=:",x)
x*=5
print("*=:",x)
x/=5
print("/=:",x)
x//=5
print("//=:",x)
x%=15
print("%=:",x)
x**=5
print("**=:",x)
# Out:
# Enter a number: 5
# +=: 10
# -=: 5
# *=: 25
# /=: 5.0
# //=: 1.0
# %=: 1.0
# **=: 1.0

# %%
#Calculate the total marks using += inside a loop.
marks = {"phy":90 ,"chem":80 , "math":100}
total = 0
for i in range(len(marks)):
  total+=marks[list(marks)[i]]
print(total)
# Out:
# 270

# %%
#Compare two numbers and print the larger number.
x = int(input("Enter first number: "))
y = int(input("Enter second number: "))
if x>y:
  print(f"{x} is larger number")
else:
  print("")
# Out:
# Enter first number: 78
# Enter second number: 56
# 78 is larger number

# %%
#Check whether three numbers are equal.
x = int(input("Enter first number: "))
y = int(input("Enter second number: "))
z = int(input("Enter third number: "))
if x==y==z:
  print("all numbers are equal")
8else:
    print("all numbers are not equal")
# Out:
# Enter first number: 56
# Enter second number: 7
# Enter third number: 44
# all numbers are not equal

# %%
#Find the largest among three numbers using comparison operators.
x = int(input("Enter first number: "))
y = int(input("Enter second number: "))
z = int(input("Enter third number: "))

if(x>y) and (x>z):
  print(f"{x} is largest number")
elif(y>x) and (y>z):
  print(f"{y} is largest number")
else:
  print(f"{z} is largest number")
# Out:
# Enter first number: 78
# Enter second number: 45
# Enter third number: 90
# 90 is largest number

# %%
#Check whether a student is eligible to vote based on age.
age = int(input("Enter your age: "))
if age>=18:
  print("you are eligible to vote")
else:
  print("you are not eligible to vote")
# Out:
# Enter your age: 17
# you are not eligible to vote

# %%
#Check if a person is eligible for a loan (age > 21 AND salary > 30000).
age = int(input("Enter your age: "))
salary = int(input("Enter your salary: "))
if age>=21 and salary>=30000:
  print("you are eligible for loan")
else:
  print("you are not eligible for loan")
# Out:
# Enter your age: 67
# Enter your salary: 8000
# you are not eligible for loan

# %%
#Check if a number lies between 10 and 100 using logical operators.
x = int(input("enter a number:"))
if x>=10 and x<=100:
  print("condition true")
else:
  print("condition false")
# Out:
# enter a number:19
# condition true

# %%
#Validate username and password using logical operators.
x = str(input("enter username:"))
y = str(input("enter password:"))
if x=="pooja" and y=="123#abc":
  print("login successful")
else:
  print("login failed")
# Out:
# enter username:pooja
# enter password:123#abc
# login successful

# %%
#Determine whether a year is a leap year using logical conditions.
x = int(input("enter year:"))
if x%4==0 and x%100!=0 or x%400==0:
  print("leap year")
else:
  print("not a leap year")
# Out:
# enter year:2026
# not a leap year

# %%
#Find the bitwise AND, OR, XOR of two numbers.
x = int(input("enter first number:"))
y = int(input("enter second number:"))
print("AND:",x&y)
print("OR:",x|y)
print("XOR",x^y)
# Out:
# enter first number:123
# enter second number:456
# AND: 72
# OR: 507
# XOR 435

# %%
#Perform left shift and right shift operations.
x = int(input("enter first number:"))
y = int(input("enter second number:"))
print("left shift:",x<<y)
print("right shift:",x>>y)
# Out:
# enter first number:3
# enter second number:7
# left shift: 384
# right shift: 0

# %%
#Check whether a number is even using a bitwise operator.
x = int(input("enter first number:"))
if x&1==0:
  print("number is even")
else:
  print("number is odd")
# Out:
# enter first number:7
# number is odd

# %%
#Swap two numbers using the XOR operator.
x = int(input("enter first number:"))
y = int(input("enter second number:"))
x=x^y
y=x^y
x=x^y
print(f"x:{x} y:{y}")
# Out:
# enter first number:2
# enter second number:4
# x:4 y:2

# %%
#Count how many bits are set to 1 in a number using bitwise operations.
x = int(input("enter first number:"))
count = 0
while x>0:
  if x&1==1:
    count+=1
  x>>=1
print(count)
# Out:
# enter first number:7
# 3

# %%
#Demonstrate the difference between is and ==.
x = [1,2,3]
y = [1,2,3]
print(x==y)
print(x is y)
# Out:
# True
# False

# %%
#Check whether two variables refer to the same list object.
x = ['a','c','d','t']

# %%
#Show the behavior of is not with integers and lists.
a = [10,40,'pqr','abc',70,90,38,'def']
def addition(a)

if

# %%
#Check whether a character exists in a string.
x =str (input("enter a string: "))
y = str(input("enter a character: "))
if y in x:
  print("character exists")
else:
  print("character not exists")
# Out:
# enter a string: data seience
# enter a character: z
# character not exists

# %%
#Check whether a number exists in a list.
x =['a','b','z','q','r']
y = str(input("enter a character: "))
if y in x:
  print("character exists")
else:
  print("character not exists")
# Out:
# enter a character: u
# character not exists

# %%
#Count how many vowels in a string belong to a predefined vowel list using in.
x = str(input("entera string:  "))
vowels = ['a','e','i','o','u']
count =0
for i in x:
  if i in vowels:
    count+=1
print(count)
# Out:
# entera string:   welcome to the data science world
# 11

# %%
#Build a simple calculator using arithmetic and comparison operators.
print("1. addition \n 2. subtraction\n 3. multiplication \n 4.division \n 5.equal to \n 6.not equal to \n 7.greater then equal to \n 8.less then equal to \n")

value = int(input("enter your choice: "))

x = int(input("Enter first number: "))
y = int(input("Enter second number: "))


if value == 1:
  print(x+y)
elif value == 2:
  print(x-y)
elif value == 3:
  print(x*y)
elif value == 4:
  print(x/y)
elif value == 5:
  print(x==y)
elif value == 6:
  if x==y:
     print("x is equal to y")
  else:
     print("x is not equal to y")
elif value == 7:
   if x>=y:
     print("x greater then y")
   else:
     print("y greater then x")
elif value == 8:
  if x<=y:
     print("x less then y")
  else:
     print("y less then x")
elif value == 8:
  print(x<=y)
else:
  print("invalid choice")
# Out:
# 1. addition
#  2. subtraction
#  3. multiplication
#  4.division
#  5.equal to
#  6.not equal to
#  7.greater then equal to
#  8.less then equal to
#
# enter your choice: 7
# Enter first number: 9
# Enter second number: 10
# y greater then x

# %%
#Create a grading system using comparison and logical operators.
marks = int(input("enter your marks: "))

if marks>=90 and marks<=100:
  print(" grade A")
elif marks>=80 and marks<=89:
     print("grade B")
elif marks>=70 and marks<=79:
    print("grade C")
elif marks>=60 and marks<=69:
    print("grade D")
elif marks>=50 and marks<=59:
    print("grade E")
elif marks>=0 and marks<=49:
    print("grade F")
# Out:
# enter your marks: 35
# grade F
